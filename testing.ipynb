# %%
import pandas as pd
import streamlit as st

# %%
### Fuções para tratar telefone: 
appointments_df = pd.read_excel("C:/Users/novo1/OneDrive/Desktop/Dev/Indique_Multiplique-1/Bases/agendamentos_colab-bi_2025-08-11 - Fechamento.xlsx")

# Collumns to use
appointments_df_columns = ['ID agendamento', 'ID cliente','Email','Telefone',
                           'Unidade do agendamento', 'Procedimento', 'Data', 'Status']

appointments_df = appointments_df[appointments_df_columns]

branches_to_consider = ['TUCURUVI', 'SANTOS', 'LAPA', 'IPIRANGA', 'COPACABANA',
                            'CAMPINAS','JARDINS', 'SOROCABA','TIJUCA','SANTO AMARO',
                            'ITAIM', 'LONDRINA', 'MOEMA','TATUAPÉ', 'MOOCA','OSASCO',
                            'ALPHAVILLE','SÃO BERNARDO', 'VILA MASCOTE', 'GUARULHOS']

appointments_df = appointments_df.loc[appointments_df['Unidade do agendamento'].isin(branches_to_consider)]

# Treating the date values
appointments_df['Data'] = pd.to_datetime(appointments_df['Data'], format='%d/%m/%Y')
appointments_df["Mes"] = appointments_df['Data'].dt.month

# Data in pt-Br format
appointments_df['Data'] = appointments_df['Data'].dt.strftime('%d/%m/%Y')

appointments_df = appointments_df.loc[appointments_df["Procedimento"].str.contains("AVALIAÇÃO",case= False)]
appointments_df = appointments_df.loc[appointments_df["Status"] == "Atendido"]

appointments_df_columns = ['ID agendamento', 'Data', 'Mes','Procedimento',
                           'Unidade do agendamento','ID cliente',
                           'Email','Telefone', 'Status']

    # Reordering the columns
appointments_df = appointments_df[appointments_df_columns]

appointments_df['Telefone'] = appointments_df['Telefone'].astype(str)

def split_Telefones(df):
# Crie uma nova lista para armazenar as novas linhas
    new_rows = []

    for _, row in df.iterrows():
        # Verifique se o valor de 'Telefones' não é nulo
        if pd.notna(row['Telefone']):
            Telefoness = row['Telefone'].split(' / ')
            for Telefones in Telefoness:
                # Crie uma nova linha para cada Telefones
                new_row = row.copy()
                new_row['Telefone'] = Telefones
                new_rows.append(new_row)

    return pd.DataFrame(new_rows)

appointments_df = split_Telefones(appointments_df)

# %%
appointments_df
# Out:
#        ID agendamento        Data  Mes                      Procedimento  \
# 1665          3047746  01/07/2025    7                AVALIAÇÃO ESTÉTICA
# 2175          3054198  05/07/2025    7  AVALIAÇÃO INJETÁVEIS E INVASIVOS
# 2350          3056057  05/07/2025    7                AVALIAÇÃO ESTÉTICA
# 2615          3058180  01/07/2025    7  AVALIAÇÃO INJETÁVEIS E INVASIVOS
# 2637          3058424  04/07/2025    7  AVALIAÇÃO INJETÁVEIS E INVASIVOS
# ...               ...         ...  ...                               ...
# 43218         3132317  29/07/2025    7  AVALIAÇÃO INJETÁVEIS E INVASIVOS
# 43219         3132318  24/07/2025    7  AVALIAÇÃO INJETÁVEIS E INVASIVOS
# 43220         3132322  29/07/2025    7  AVALIAÇÃO INJETÁVEIS E INVASIVOS
# 43240         3133130  18/07/2025    7  AVALIAÇÃO INJETÁVEIS E INVASIVOS
# 43244         3133286  21/07/2025    7  AVALIAÇÃO INJETÁVEIS E INVASIVOS
#
#       Unidade do agendamento  ID cliente  \
# 1665                  OSASCO     1044899
# 2175              ALPHAVILLE     1045743
# 2350                   MOOCA     1046039
# 2615                 JARDINS     1046296
# 2637              COPACABANA     1045339
# ...                      ...         ...
# 43218               LONDRINA      218311
# 43219               LONDRINA     1051976
# 43220               LONDRINA     1052775
# 43240               SOROCABA     1051784
# 43244               SOROCABA     1052266
#
#                                       Email     Telefone    Status
# 1665               Karinedso@hotmail.com.br  11998094948  Atendido
# 2175                     fabiolreis@msn.com  11954181986  Atendido
# 2350                   Lu.rocha86@gmail.com  11992559097  Atendido
# 2615                    rfprocop7@gmail.com  11992494352  Atendido
# 2637              luisianneararas@gmail.com  21981579613  Atendido
# ...                                     ...          ...       ...
# 43218           rebeca.carlucci@hotmail.con   4396572596  Atendido
# 43219  caseiagora.janainavolpiani@gmail.com  43984770925  Atendido
# 43220          fit.flaviagarcia@hotmail.com  43996815429  Atendido
# 43240             manuelaalice500@gmail.com  15998264451  Atendido
# 43244         telmagutierressilva@gmail.com  15988256577  Atendido
#
# [2730 rows x 9 columns]

# %%
# Carregar o arquivo Excel
xls = pd.ExcelFile('C:/Users/novo1/OneDrive/Desktop/Dev/Indique_Multiplique-1/Bases/compartilhamentos_20250820110351.xlsx')

# Lista para guardar os dataframes de cada aba
dfs = []

# Iterar por cada aba
for sheet_name in xls.sheet_names:
    # Ler a aba
    df = pd.read_excel(xls, sheet_name=sheet_name)
    # Selecionar colunas específicas
    # Adicionar coluna 'Unidade' com o nome da aba
    df['Unidade'] = sheet_name
    df['Unidade'] = df['Unidade'].str.upper()
    # Append ao lista
    dfs.append(df)

# Concatenar todos os dataframes
indique_df = pd.concat(dfs, ignore_index=True)

indique_df['Telefone compartilhador'] = indique_df['Telefone compartilhador'].astype(str)

indique_df
# Out:
#        ID           Compartilhador           Email compartilhador  \
# 0    1801         Venância  Araujo    Venanciaaraujo@yahoo.com.br
# 1    1799           Rosilda Dantas     rosildadantas655@gmail.com
# 2    1796         Elisangela silva           esilva2113@gmail.com
# 3    1795                 Patrícia  patriciacunhacampos@gmail.com
# 4    1793                    Laura           laura.leite@live.com
# ..    ...                      ...                            ...
# 677   303           Carlos Andrade    Go.carlos.andrade@gmail.com
# 678   301  VANESSA SANTOS DE SOUZA        nessaramires1@gmail.com
# 679   300  VANESSA SANTOS DE SOUZA        nessaramires1@gmail.com
# 680   296  VANESSA SANTOS DE SOUZA        nessaramires1@gmail.com
# 681   295         Ana Amorim diniz         anadinizana1@gmail.com
#
#     Telefone compartilhador                      Consultor  \
# 0               11963193044    Sabrina Oliveira Dias Sousa
# 1               11988515851    Sabrina Oliveira Dias Sousa
# 2               11985459498    Sabrina Oliveira Dias Sousa
# 3               34992729460    Sabrina Oliveira Dias Sousa
# 4               11974841952    Sabrina Oliveira Dias Sousa
# ..                      ...                            ...
# 677             11977933000            Sarah leal oliveira
# 678             11957713050            Sarah leal oliveira
# 679             11957713050            Sarah leal oliveira
# 680             11957713050            Sarah leal oliveira
# 681             11958726211  Beatriz Nogueira de  Oliveira
#
#                                               Campanha            Criado em  \
# 0    Tem alguém especial? Indique para a Pró-Corpo ...  31/07/2025 22:58:36
# 1    Tem alguém especial? Indique para a Pró-Corpo ...  31/07/2025 22:50:01
# 2    Tem alguém especial? Indique para a Pró-Corpo ...  31/07/2025 22:41:54
# 3    Tem alguém especial? Indique para a Pró-Corpo ...  31/07/2025 22:38:32
# 4    Tem alguém especial? Indique para a Pró-Corpo ...  31/07/2025 22:31:15
# ..                                                 ...                  ...
# 677  Vamos editar a campanha Tem alguém especial? I...  03/07/2025 18:36:57
# 678  Vamos editar a campanha Tem alguém especial? I...  03/07/2025 18:14:47
# 679  Vamos editar a campanha Tem alguém especial? I...  03/07/2025 18:11:45
# 680  Vamos editar a campanha Tem alguém especial? I...  03/07/2025 17:30:50
# 681  Vamos editar a campanha Tem alguém especial? I...  02/07/2025 10:50:18
#
#          Rede Leads Gerados       Unidade
# 0    WhatsApp             2    ALPHAVILLE
# 1    WhatsApp             0    ALPHAVILLE
# 2    WhatsApp             9    ALPHAVILLE
# 3    WhatsApp             2    ALPHAVILLE
# 4    WhatsApp             5    ALPHAVILLE
# ..        ...           ...           ...
# 677  WhatsApp             6  VILA MASCOTE
# 678  WhatsApp             0  VILA MASCOTE
# 679  WhatsApp             2  VILA MASCOTE
# 680  WhatsApp             2  VILA MASCOTE
# 681  WhatsApp             0  VILA MASCOTE
#
# [682 rows x 10 columns]

# %%
indique_appointments_merge_email = pd.merge(indique_df,appointments_df[['Email','ID agendamento','Data','ID cliente', 'Status']],
                                      left_on='Email compartilhador',
                                      right_on='Email',
                                      how='left'
                                      )

indique_appointments_merge_telefone = pd.merge(indique_df,appointments_df[['Telefone','ID agendamento','Data','ID cliente', 'Status']],
                                      left_on='Telefone compartilhador',
                                      right_on='Telefone',
                                      how='left'
                                      )



indique_appointments_merge_final = pd.concat([indique_appointments_merge_email,indique_appointments_merge_telefone])

indique_appointments_merge_final = indique_appointments_merge_final.loc[~indique_appointments_merge_final['ID agendamento'].isna()]

indique_appointments_merge_final = indique_appointments_merge_final.drop_duplicates(subset=['ID'])

base_indique_final = indique_appointments_merge_final

base_indique_final_columns = ['ID', 'Compartilhador', 'Email compartilhador',
                                'Telefone compartilhador', 'Consultor','Unidade', 'Criado em',
                                'ID agendamento', 'Data','ID cliente', 'Status','Leads Gerados']

base_indique_final = base_indique_final[base_indique_final_columns]


## Aguardando confirmação da Pat se consider ou não.
# duplicados = base_indique_final.loc[base_indique_final['ID agendamento'].duplicated(keep=False)]

# duplicados = duplicados.sort_values(by=['ID agendamento'])

# duplicados

indique_gp = base_indique_final.groupby(["Consultor",'Unidade']).agg({'Leads Gerados' : 'sum'}).reset_index()

indique_gp = indique_gp.sort_values(by=['Leads Gerados'],ascending=False).reset_index(drop=True)

indique_gp
# Out:
#                              Consultor       Unidade Leads Gerados
# 0          Sabrina Oliveira Dias Sousa    ALPHAVILLE            78
# 1               Camilly Giselle Barros        OSASCO            74
# 2                         Debora Souza      LONDRINA            58
# 3       Ingrid Caroline Santos Andrade      CAMPINAS            50
# 4               Fernanda Machado Leite        TIJUCA            36
# 5                Amanda Raquel Cassula      LONDRINA            20
# 6             Laysla Ferreira de Jesus     GUARULHOS            18
# 7                Vitoria Almeida Silva        OSASCO            15
# 8                        Nicolly Alves          LAPA            15
# 9                                    -          LAPA            12
# 10               Thamyres Lima Marques        TIJUCA            11
# 11  Isabelle pellegrini de Albuquerque   SANTO AMARO             9
# 12        Renally carla da silva moura    COPACABANA             9
# 13                   Larissa Rodrigues    ALPHAVILLE             7
# 14            Aline Araujo de Oliveira     GUARULHOS             7
# 15                                   -       TATUAPÉ             7
# 16                      Larissa Sabino         MOEMA             6
# 17            Thais Dias Souza Vasquez         MOEMA             5
# 18                        Yasmin Ramos  SÃO BERNARDO             5
# 19        Camylli Victoria Lonis Silva      TUCURUVI             5
# 20                           Gabrielly       TATUAPÉ             3
# 21                Loren Schiavo Araujo        SANTOS             1
# 22      Lorrana Assis Santana de Souza   SANTO AMARO             1
# 23                      Jennifer Lopes      TUCURUVI             1
# 24           Isabelly da Silva Miranda         ITAIM             1
# 25     Iasmin Monteiro Dias dos Santos      IPIRANGA             1
# 26             Karisa da Silva Pereira         MOOCA             1
# 27                     Mariana Almeida        SANTOS             0
# 28                 Sarah leal oliveira  VILA MASCOTE             0
# 29       Beatriz Nogueira de  Oliveira  VILA MASCOTE             0

# %%
indique_gp.to_excel("C:/Users/novo1/OneDrive/Desktop/Dev/Indique_Multiplique-1/Bases/Indique_&_multiplique_até_14-08.xlsx")
